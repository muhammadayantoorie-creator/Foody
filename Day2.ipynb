# %% [markdown]
# <a href="https://colab.research.google.com/github/muhammadayantoorie-creator/Foody/blob/main/Day2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Variables, are the containers that store the data types in computer memory

#Storing a name in a variable
name = "Ayan"
nameOfPerson = "Muhammad"

# Storing an age in a variable
age = 42

print(name)
print(nameOfPerson)
print(age)
# Out:
# Ayan
# Muhammad
# 42

# %%
#Datatyes, python has different datatypes for storing different type of information

#string
name = "Ayan"
#interger
age = 20
# Float
height = 5.8
#boolean
is_student = True
is_student = False

print(type(name))
print(type(age))
print(type(height))
print(type(is_student))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'bool'>

# %%
#Typeconversion/ typecasting, is the conversion of one datatype into the others datatype

age = 19
myAge = str(age)
print(type(myAge))

age = "19"
myAge = int(age)
print(type(myAge))

age = 19
myAge = str(age)
print(myAge)

age = "19"
myAge = int(age)
print(myAge)

age = 19
myAge = str(age)
print(myAge )

age = "19"
myAge = int(age)
print(myAge +5)

x = 10
y = 20.55
z = x+y
print(z)
print(type(z))
# Out:
# <class 'str'>
# <class 'int'>
# 19
# 19
# 19
# 24
# 30.55
# <class 'float'>

# %%
#String format, process of inserting variables and values into the text string to create a dynamic and customized message

name = "Ayan"
print("Hello," + name +"!")
print("Hello My Friend, {}!".format(name))
print(f"Hello, {name}!")
# Out:
# Hello,Ayan!
# Hello My Friend, Ayan!
# Hello, Ayan!

# %%
#Day2 project, Personalized Greeting Program

#step1: asked for user details
name = input("What is your name?")
age = int(input("How old are you?"))
color = input("What is your favorite color")

#step2: Greet the user
print("\n-- Personalized Greeting--")
print(f"Hello, {name}!")
print(f"You are {age} years old and {color} is a beautiful color!")
print("You are  now ready to start your Python Jounery.")
# Out:
# What is your name?Ayan
# How old are you?20
# What is your favorite colorYellow
#
# -- Personalized Greeting--
# Hello, Ayan!
# You are 20 years old and Yellow is a beautiful color!
# You are  now ready to start your Python Jounery.

# %%
name = "Ayan"
age = "20"
city = "Parachinar"
print(f"Hello my Friend,{name},you are {age} years old,you are from {city} which is so amazing and beautiful.")
# Out:
# /n---Message---
# Hello my Friend,Ayan,you are 20 years old,you are from Parachinar which is so amazing and beautiful.
