# %% [markdown]
# <a href="https://colab.research.google.com/github/muhammadayantoorie-creator/Foody/blob/main/Day10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#File handling:is Python's way of reading data from and writing data to files on your computer, enabling permanent data storage and retrieval.

# For reading text file: ___
# ANSWER: 'r'

# For writing binary: ___
# ANSWER: 'wb'

# For appending text: ___
# ANSWER: 'a'

# For exclusive creation: ___
# ANSWER: 'x'

# For read and write: ___
# ANSWER: 'r+'

# For append binary: ___
# ANSWER: 'ab'

# For read binary: ___
# ANSWER: 'rb'

# For write text (overwrite): ___
# ANSWER: 'w'

# For read and write binary: ___
# ANSWER: 'rb+'

# For write and read: ___
# ANSWER: 'w+'



#BAsic Syntax:
# Using open() function
file = open('filename.txt', 'mode')

# Always close files
file.close()

# %%
with open("notes.txt","r") as file: #Reading from file
  content = file.read()
  print(content)
# Out:
# Hello! this is the first note of Muhammad Ayan.

# %%
with open("notes.txt","w") as file: #Writing from file
  file.write("\n This is my new notes.\n")

# %%
with open("notes1.txt","w") as file: #if file is not exists,then automatically created
  file.write("\n This is my new notes.\n")

# %%
with open("notes.txt","a") as file: #appending to file
  file.write("\n This is my new notes for python programming.\n")

# %%
with open("notes1.txt","a") as file: #appending to file
  file.write("\n This is my new notes for python programming.\n")

# %%
#Day10 project:Note-Taking App

#Step2: Define file notes
FILE_NAME = "myNotes.txt"

#Step3: Display menu option
def show_menu():
  print("\n--- Note Taking App Menu---")
  print("1. Add  a new Notes")
  print("2. View all Notes")
  print("3. Delete all Notes")
  print("4. Exit")

#Step3:Add a new notes
def add_notes():
  notes = input("Enter the new notes:")
  with open(FILE_NAME,"a") as file:
    file.write(notes + "\n")
  print("Notes added successfully!")

#Step4: view all notes
def view_notes():
  try:
    with open(FILE_NAME,"r") as file:
      content = file.read()
      if content:
        print("\n---Your Notes---")
        print(content)
      else:
        print("\n---No Notes found.")
  except FileNotFoundError:
    print("No notes found")

#Step5:Delete all notes
def delete_notes():
  confirm = input("Are you sure want to delete all notes? (Yes/n)")
  if confirm.lower() == "yes":
    with open(FILE_NAME,"w") as file:
      pass
    print("All notes have been deleted!")
  else:
    print("Deletion cancelled")

#Step6: Main program loop
while True:
  show_menu()
  choice = input("Enter your choice (1-4):")
  if choice == "1":
    add_notes()
  elif choice == "2":
    view_notes()
  elif choice == "3":
    delete_notes()
  elif choice == "4":
    print("Exiting Note Taking App.Goodbye!")
    break
  else:
    print("Invalid choice. Please enter a number between 1 and 4.")
# Out:
# --- Note Taking App Menu---
# 1. Add  a new Notes
# 2. View all Notes
# 3. Delete all Notes
# 4. Exit
# Enter your choice (1-4):5
# Invalid choice. Please enter a number between 1 and 4.
#
# --- Note Taking App Menu---
# 1. Add  a new Notes
# 2. View all Notes
# 3. Delete all Notes
# 4. Exit
# Enter your choice (1-4):1
# Enter the new notes:Learn python from Muhammad Ayan
# Notes added successfully!
#
# --- Note Taking App Menu---
# 1. Add  a new Notes
# 2. View all Notes
# 3. Delete all Notes
# 4. Exit
# Enter your choice (1-4):2
#
# ---Your Notes---
# Learn python
# Learn python from Muhammad Ayan
# Learn python from Muhammad Ayan
#
#
# --- Note Taking App Menu---
# 1. Add  a new Notes
# 2. View all Notes
# 3. Delete all Notes
# 4. Exit
# Enter your choice (1-4):3
# Are you sure want to delete all notes? (Yes/n)if
# Deletion cancelled
#
# --- Note Taking App Menu---
# 1. Add  a new Notes
# 2. View all Notes
# 3. Delete all Notes
# 4. Exit
# Enter your choice (1-4):3
# ...
