# %% [markdown]
# <a href="https://colab.research.google.com/github/muhammadayantoorie-creator/Foody/blob/main/Day8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Dictionaries:A dictionary is a collection of key-value pairs where each key maps to a value. Keys must be unique and immutable (like strings or numbers), while values can be any data type.
my_dict = {
    "key1": "value1",
    "key2": "value2",
    "key3": "value3"
}

# %%
contact = {
    "name": "Ayan",
    "phone": "123-456-789",
    "city": "Parachinar",
    "email": "md.ayan.turi@example-pet-store.com"
}
print(contact ["phone"])
# Out:
# 123-456-789

# %%
contact = {
    "name": "Ayan",
    "phone": "123-456-789",
    "city": "Parachinar",
    "email": "md.ayan.turi@example-pet-store.com"
}
print(contact ["name"])
print(contact ["phone"])
print(contact ["city"])
print(contact ["email"])
# Out:
# Ayan
# 123-456-789
# Parachinar
# md.ayan.turi@example-pet-store.com

# %%
dict_example = {
    "fruits": ["apple", "banana", "cherry"],
    "color": ["red", "yellow", "blue"],
    "number": [1, 2, 3]
}
print(dict_example["fruits"])
# Out:
# ['apple', 'banana', 'cherry']

# %%
# Empty dictionary
empty_dict = {}

# With data
student = {
    "name": "Ayan",
    "age": 20,
    "grade": "A",
    "subjects": ["CAL1", "DB", "DLD"]  # Can have lists!
}

# Using dict() constructor
person = dict(name="Ayan", age=20, city="Parachinar")

# %%
#Accessing and Modifying Dictionary Values
contact = {
    "name": "Ayan",
    "phone": "123-456-789",
    "city": "Parachinar",
    "email": "md.ayan.turi@example-pet-store.com"
}
print(contact.get("name"))

contact["phone"] = "987-654-321"
print(contact)

del contact["email"]
print(contact)
# Out:
# Ayan
# {'name': 'Ayan', 'phone': '987-654-321', 'city': 'Parachinar', 'email': 'md.ayan.turi@example-pet-store.com'}
# {'name': 'Ayan', 'phone': '987-654-321', 'city': 'Parachinar'}

# %%
#loop in dictionary
contact = {
    "name": "Ayan",
    "phone": "123-456-789",
    "city": "Parachinar",
    "email": "md.ayan.turi@example-pet-store.com"
}
for key, value in  contact.items():
    print(key,value)
# Out:
# name Ayan
# phone 123-456-789
# city Parachinar
# email md.ayan.turi@example-pet-store.com

# %%
contact = {
    "name": "Ayan",
    "phone": "123-456-789",
    "city": "Parachinar",
    "email": "md.ayan.turi@example.com"
}
for key, value in  contact.items():
    print(f"{key}:{value}")
if"email" in contact:
  print("Email found!")
else:
  print("Email not found!")
# Out:
# name:Ayan
# phone:123-456-789
# city:Parachinar
# email:md.ayan.turi@example.com
# Email found!

# %%
#Day8 project: contact book

#step1:initalize the contact book
contact = {}

#Step2: Display the menu
def show_menu():
  print("\n---Contact Book Menu---")
  print("1. Add Contact")
  print("2. View Contact")
  print("3. Search Contact")
  print("4. Edit Contact")
  print("5. Delete Contact")
  print("6. Exit")

#Step3: Add the contact
def add_contact():
  name = input("Enter Contact name: ")
  phone = input("Enter Contact phone: ")
  email = input("Enter Contact email: ")
  contact[name] = {"phone": phone, "email": email}
  print(f"Contact {name} added successfully!")
#step4: View all contacts
def view_contact():
  if contact:
    print("\n---Contact Book---")
    for name, details in contact.items():
      print(f"Name: {name}")
      print(f"Phone: {details['phone']}")
      print(f"Email: {details['email']}")
  else:
    print("Contact book is empty!")

 #step5: search a contact
def search_contact():
  name = input("Enter Contact name to search: ")
  if name in contact:
    print(f"\n---Contact detail for {name}---")
    print(f"Name: {name}")
    print(f"Phone: {contact[name]['phone']}")
    print(f"Email: {contact[name]['email']}")
  else:
    print(f"Contact {name} not found in your contact book!")

#Step6: Edit a contact
def edit_contact():
  name = input("Enter Contact name to edit: ")
  if name in contact:
     phone = input("Enter new contact phone: ")
     email = input("Enter new contact email: ")
     contact[name] = {"phone": phone, "email": email}
     print(f"Contact {name} edited successfully!")
  else:
    print(f"Contact {name} not found in your contact book!")

#Step7:Delete the menu
def delete_contact():
  name = input("Enter Contact name to delete: ")
  if name in contact:
    del contact[name]
    print(f"Contact {name} deleted successfully!")
  else:
    print(f"Contact {name} not found in your contact book!")

#Step8: Main Program loop
while True:
  show_menu()
  choice = input("Enter your choice (1-6): ")

  if choice == "1":
    add_contact()
  elif  choice == "2":
    view_contact()
  elif  choice == "3":
    search_contact()
  elif  choice == "4":
    edit_contact()
  elif  choice == "5":
    delete_contact()
  elif choice == "6":
    print("Thank you for using the contact Book.Goodbye!")
    break
  else:
    print("Invalide choice! Please select a valide choice(1-6).")
# Out:
# ---Contact Book Menu---
# 1. Add Contact
# 2. View Contact
# 3. Search Contact
# 4. Edit Contact
# 5. Delete Contact
# 6. Exit
# Enter your choice (1-6): 1
# Enter Contact name: Ayan
# Enter Contact phone: 123456765
# Enter Contact email: ayan@.com
# Contact Ayan added successfully!
#
# ---Contact Book Menu---
# 1. Add Contact
# 2. View Contact
# 3. Search Contact
# 4. Edit Contact
# 5. Delete Contact
# 6. Exit
# Enter your choice (1-6): 2
#
# ---Contact Book---
# Name: Ayan
# Phone: 123456765
# Email: ayan@.com
#
# ---Contact Book Menu---
# 1. Add Contact
# 2. View Contact
# 3. Search Contact
# 4. Edit Contact
# 5. Delete Contact
# 6. Exit
# Enter your choice (1-6): 3
# Enter Contact name to search: Ayan
#
# ---Contact detail for Ayan---
# Name: Ayan
# Phone: 123456765
# Email: ayan@.com
#
# ---Contact Book Menu---
# 1. Add Contact
# 2. View Contact
# 3. Search Contact
# 4. Edit Contact
# 5. Delete Contact
# 6. Exit
# Enter your choice (1-6): 4
# Enter Contact name to edit: Ayan
# ...
