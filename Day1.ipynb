# %% [markdown]
# <a href="https://colab.research.google.com/github/muhammadayantoorie-creator/Foody/blob/main/Day1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("YOur message is here") #Print Statement
# Out:
# YOur message is here

# %%
print("Hello! Programming World")
# Out:
# Hello! Programming World

# %%
print("The Number is" ,4) #print with text and numbers
print("2 + 2 =" ,2+2)
# Out:
# The Number is 4
# 2 + 2 = 4

# %%
name ="Ayan" #string formatting for the dymanic message
print("Hello,{name}! Wellcome to Python Programming")
# Out:
# Hello,{name}! Wellcome to Python Programming

# %%
name ="Ayan"
print(f"Hello,{name}! Wellcome to Python Programming")
# Out:
# Hello,Ayan! Wellcome to Python Programming

# %%
# using user input with print
userName =input("What is your name? ")
print(f"Hello, {userName}! Wellcome to the python programming")
# Out:
# What is your name? Ayan
# Hello, Ayan! Wellcome to the python programming

# %%
# Day 1 project welcome message generator

#step1: Ask for user Details
name = input("What is your name?")
hobby = input("What is your favorite Hobby?")

#step2 generate the welcome message
print("\n--- Welcome Message ---")
print(f"Hello, {name}!")
print("Welcome to the world of Python Programming.")
print(f"It's great to know that you love {hobby}.")
print("Get ready to built something amazing today.")
# Out:
# What is your name?Ayan
# What is your favorite Hobby?Reading
#
# --- Welcome Message ---
# Hello, Ayan!
# Welcome to the world of Python Programming.
# It's great to know that you love Reading.
# Get ready to built something amazing today.
