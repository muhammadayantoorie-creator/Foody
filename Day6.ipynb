# %% [markdown]
# <a href="https://colab.research.google.com/github/muhammadayantoorie-creator/Foody/blob/main/Day6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Function,  it's a block of code that you can use over and over again by just calling its name.

 def function_name():
  #Code block inside the function

# %%
def greet():
  print("Hello,Welcome to the python jounery")
greet()
# Out:
# Hello,Welcome to the python jounery

# %%
def say_hello():
  print("Hello, friends I am here")
say_hello()
# Out:
# Hello, friends I am here

# %%
#function calling,means telling Python to run that function
def say_hello():
  print("Hello, friends I am here")
say_hello()
say_hello()
say_hello()
# Out:
# Hello, friends I am here
# Hello, friends I am here
# Hello, friends I am here

# %%
#Function Parameters and Arguments;
#Parameters = the placeholders
#Arguments = the actual values

def greet(name): #placeholders
  print(f"Hello,{name}! Welcome to the python Programming")
greet("Ayan") # Actual value
# Out:
# Hello,Ayan! Welcome to the python Programming

# %%
def greet_user(name):
  print(f"Hello,{name}! Welcome to the python Programming")
greet_user("Ayan")
# Out:
# Hello,Ayan! Welcome to the python Programming

# %%
def say_hello(name):
  print(f"Hello! {name}")
say_hello("Muhammad")
say_hello("Ayan")
# Out:
# Hello! Muhammad
# Hello! Ayan

# %%
def greet(first_name , last_name):
  print(f"Hello, {first_name} {last_name}")
greet("Muhammad", "Ayan")
greet("Waqar", "Ahmed")
# Out:
# Hello, Muhammad Ayan
# Hello, Waqar Ahmed

# %%
def add(a,b):
  print(f"The sum is:{a + b}")
add(3 , 6)
# Out:
# The sum is:9

# %%
def person(name , age , city):
  print(f"{name} age of {age} years old from {city}.")
person("Ayan", 20, "Parachinar")
# Out:
# Ayan age of 20 years old from Parachinar.

# %%
def add(x , y):
  return x + y
result1 = add(5,7)
result2 = add(12,7)
result3 = add(177,7)
print(result1)
print(result2)
print(result3)
# Out:
# 12
# 19
# 184

# %%
def multifly(a , b):
  return a * b
result = multifly(7,7)
print("The result is:",result)
# Out:
# The result is: 49

# %%
# Day6 project: Basic Math Quiz Game

import random

# Step 1: Define the math question function
def generate_question():
    num1 = random.randint(1, 10)
    num2 = random.randint(1, 5)
    operator = random.choice(['+', '-', '*', '/'])

    if operator == '+':
        answer = num1 + num2
    elif operator == '-':
        answer = num1 - num2
    elif operator == '*':
        answer = num1 * num2
    else:
        answer = round(num1 / num2, 2)  # Round to 2 decimal places

    return f"{num1} {operator} {num2}", answer

# Step 2: Main quiz game function
def math_quiz():
    score = 0
    rounds = 5

    print("\n---- Welcome to Math Quiz Game ----")
    print("You will be presented with math problems, and you need to provide the correct answers.")

    for i in range(rounds):
        question, correct_answer = generate_question()
        print(f"\nQuestion {i+1}: {question}")

        # Use float to handle decimal answers from division
        try:
            user_answer = float(input("Your answer: "))
        except ValueError:
            print("Please enter a valid number!")
            user_answer = 0

        if user_answer == correct_answer:
            print("Correct!")
            score += 1
        else:
            print(f"Wrong! The correct answer is: {correct_answer}")

    print("\n---- Game Over ----")
    print(f"Your final score is: {score}/{rounds}")

    if score == rounds:
        print("Congratulations! You got all the questions correct!")
    elif score >= rounds // 2:
        print("Good job! You did well.")
    else:
        print("Keep practicing! You can do better next time.")

# Step 3: Run the quiz
math_quiz()
# Out:
# ---- Welcome to Math Quiz Game ----
# You will be presented with math problems, and you need to provide the correct answers.
#
# Question 1: 7 / 5
# Your answer: 3
# Wrong! The correct answer is: 1.4
#
# Question 2: 6 / 1
# Your answer: 6
# Correct!
#
# Question 3: 8 - 3
# Your answer: 4
# Wrong! The correct answer is: 5
#
# Question 4: 7 * 1
# Your answer: 7
# Correct!
#
# Question 5: 5 - 1
# Your answer: 4
# Correct!
#
# ---- Game Over ----
# Your final score is: 3/5
# Good job! You did well.
